# %%
library(cubature)
library(MASS)
library(pracma)
library(mvtnorm)

library(LogConcDEAD)
library(logcondens) 

library(plot3D)

library(mclust)

# %%
source('lcic.r')

# %%
sessionInfo()
# Out:
# R version 4.3.1 (2023-06-16)
# Platform: x86_64-conda-linux-gnu (64-bit)
# Running under: Red Hat Enterprise Linux 8.9 (Ootpa)
#
# Matrix products: default
# BLAS/LAPACK: /zfs/users/sharvaj/sharvaj/.conda/envs/r_env_logconcindcomp/lib/libopenblasp-r0.3.24.so;  LAPACK version 3.11.0
#
# locale:
#  [1] LC_CTYPE=en_US.UTF-8       LC_NUMERIC=C
#  [3] LC_TIME=en_US.UTF-8        LC_COLLATE=en_US.UTF-8
#  [5] LC_MONETARY=en_US.UTF-8    LC_MESSAGES=en_US.UTF-8
#  [7] LC_PAPER=en_US.UTF-8       LC_NAME=C
#  [9] LC_ADDRESS=C               LC_TELEPHONE=C
# [11] LC_MEASUREMENT=en_US.UTF-8 LC_IDENTIFICATION=C
#
# time zone: America/Vancouver
# tzcode source: system (glibc)
#
# attached base packages:
# [1] stats     graphics  grDevices utils     datasets  methods   base
#
# other attached packages:
# [1] mclust_6.0.1      plot3D_1.4        logcondens_2.1.8  LogConcDEAD_1.6-8
# [5] mvtnorm_1.2-3     pracma_2.4.2      MASS_7.3-60       cubature_2.1.0
#
# loaded via a namespace (and not attached):
# ...

# %% [markdown]
# # First and second figures: demonstrate on 2D densities, Gaussian and Gamma
# Fix $r = 0.5$

# %% [markdown]
# ## Gaussian
# We use $\Sigma_Z = \mathrm{Diag}(6,3)$, and $W$ randomly chosen.

# %%
d = 2
n = 1000
true_mean_vec <- rep(0,d) 
Sigma_max = 6
eigensep = 3

SimData <- get_heteroskedastic_gaussian_data(d, n, true_mean_vec, Sigma_max=Sigma_max, eigensep=eigensep)
# Out:
# [1] "Diagonal covariance: "
#      [,1] [,2]
# [1,]    6    0
# [2,]    0    3

# %%
plot(x=SimData$pre_data[,1], y=SimData$pre_data[,2], asp=1)
# Out:
# plot without title

# %%
# Fulldim
t_start <- Sys.time()
my_fulldim_output <- generate_fulldim_log_concave_estimator(SimData)
t_end <- Sys.time()
time_taken_fulldim <- difftime(t_end, t_start, units="secs")

time_taken_fulldim
# Out:
# Time difference of 59.97507 secs

# %%
my_fulldim_output$optflag
# Out:
# [1] 0

# %%
split_r <- 0.5

t_start <- Sys.time()
my_estimator_logcondens <- generate_estimator_with_logcondens(SimData, r=split_r, plotting=FALSE)
t_end <- Sys.time()
time_taken_lcic <- difftime(t_end, t_start, units="secs")

time_taken_lcic
# Out:
# [1] "PCA done!"
# [1] "Marginal: "
# [1] 1
# [1] "Marginal: "
# [1] 2
# Time difference of 0.1041245 secs

# %%
# Helper functions for computing sq hellinger errors

hfun_logcondens <- function(X_samps){
    density_ratio <- evaluate_logcondens_estimator_vectorized(X_samps, my_estimator_logcondens)/heteroskedastic_gaussian_pdf_vectorized(X_samps, SimData)
    return(0.5*(sqrt(density_ratio)-1)^2)
}


hfun_fulldim <- function(X_samps){
    density_ratio <- evaluate_fulldim_estimator_vectorized(X_samps, my_fulldim_output$my_fulldim_estimator)/heteroskedastic_gaussian_pdf_vectorized(X_samps, SimData)
    return(0.5*(sqrt(density_ratio)-1)^2)
}

generate_heteroskedastic_gaussian_samples_for_monte_carlo <- function(K_samps){
    return(mvrnorm(K_samps, mu=rep_len(0,d), Sigma=SimData$covariance_X))
}

# Error of proposed
K_samps <- 10000
num_repeats <- 100

hellinger_error_estimate_statistics_logcondens <- naive_monte_carlo_integrate_repeated(hfun_logcondens, 
                                                    generate_heteroskedastic_gaussian_samples_for_monte_carlo, K_samps, num_repeats)


hellinger_error_estimate_statistics_fulldim <- naive_monte_carlo_integrate_repeated(hfun_fulldim, 
                                                generate_heteroskedastic_gaussian_samples_for_monte_carlo, K_samps, num_repeats)

# %%
print(hellinger_error_estimate_statistics_logcondens$mean_val)
print(hellinger_error_estimate_statistics_logcondens$sd_val)
# Out:
# [1] 0.007976394
# [1] 0.0005118906

# %%
print(hellinger_error_estimate_statistics_fulldim$mean_val)
print(hellinger_error_estimate_statistics_fulldim$sd_val)
# Out:
# [1] 0.006276886
# [1] 0.0004660904

# %%
# pdf(file='Results/First-figures/indep_dir_plot.pdf', width=4, height=4)
pdf(file='Results/First-figures/indep_dir_plot.pdf')
visualize_independent_directions(SimData, my_estimator_logcondens, xlim=c(-1,1), ylim=c(-1,1))
dev.off()
# Out:
#        [,1]        [,2]
# Comp.1  0.99832404 0.05787145
# Comp.2 -0.05787145 0.99832404
# png
#   2

# %%
# Plotting densities
xg <- seq(-7, 7, by=.2)
yg <- xg

gridmat <- data.matrix(expand.grid(xg, yg))

# %%
z_vals_gt <- matrix(heteroskedastic_gaussian_pdf_vectorized(gridmat, SimData), nrow=length(xg))

z_vals_fulldim <- matrix(evaluate_fulldim_estimator_vectorized(gridmat, my_fulldim_output$my_fulldim_estimator), nrow=length(xg))

z_vals_lcic <- matrix(evaluate_logcondens_estimator_vectorized(gridmat, my_estimator_logcondens), nrow=length(xg))

# %%
# dev.new(width=7, height=4, unit="in")
theta <- 10
phi <- 20
# pdf(file='Results/First-figures/compare-visually-gaussian.pdf', width=14, height=10)
options(repr.plot.width = 14, repr.plot.height = 10)
par(mfrow = c(2, 3))
persp(xg, yg, z_vals_gt, theta=theta, phi=phi, box=FALSE)
persp(xg, yg, z_vals_fulldim, theta=theta, phi=phi, box=FALSE)
persp(xg, yg, z_vals_lcic, theta=theta, phi=phi, box=FALSE)

contour(xg, yg, z_vals_gt, xlab=expression(x[1]), ylab=expression(x[2]), cex.lab=1.5, cex.axis=1.5, drawlabels=FALSE)
contour(xg, yg, z_vals_fulldim, xlab=expression(x[1]), ylab=expression(x[2]), cex.lab=1.5, cex.axis=1.5, drawlabels=FALSE)
contour(xg, yg, z_vals_lcic, xlab=expression(x[1]), ylab=expression(x[2]), cex.lab=1.5, cex.axis=1.5, drawlabels=FALSE)
# dev.off()
# Out:
# png
#   2

# %% [markdown]
# ## Gamma
# We use $W = I$ with $Z_1 \sim \mathrm{Gamma}(6, 1)$ and $Z_1 \sim \mathrm{Gamma}(3, 1)$.

# %%
d = 2
n = 1000
# true_mean_vec <- rep(0,d) 
Sigma_max = 6
eigensep = 3

SimData <- get_axis_aligned_heteroskedastic_gamma_data(d, n, Sigma_max=Sigma_max, eigensep=eigensep)
options(repr.plot.width = 7, repr.plot.height = 7)
plot(x=SimData$pre_data[,1], y=SimData$pre_data[,2], asp=1)
# Out:
# plot without title

# %%
# # Fulldim
# my_fulldim_output <- generate_fulldim_log_concave_estimator(SimData)
# my_fulldim_output$optflag

# Fulldim
t_start <- Sys.time()
my_fulldim_output <- generate_fulldim_log_concave_estimator(SimData)
t_end <- Sys.time()
time_taken_fulldim <- difftime(t_end, t_start, units="secs")

time_taken_fulldim
# Out:
# Time difference of 47.35839 secs

# %%
split_r <- 0.5

t_start <- Sys.time()
my_estimator_logcondens <- generate_estimator_with_logcondens(SimData, r=split_r, plotting=FALSE)
t_end <- Sys.time()
time_taken_lcic <- difftime(t_end, t_start, units="secs")

time_taken_lcic
# Out:
# [1] "PCA done!"
# [1] "Marginal: "
# [1] 1
# [1] "Marginal: "
# [1] 2
# Time difference of 0.07661247 secs

# %%
# Assess error
hfun_logcondens <- function(X_samps){
    density_ratio <- evaluate_logcondens_estimator_vectorized(X_samps, my_estimator_logcondens)/axis_aligned_heteroskedastic_gamma_pdf_vectorized(X_samps, SimData)
    return(0.5*(sqrt(density_ratio)-1)^2)
}

hfun_fulldim <- function(X_samps){
    density_ratio <- evaluate_fulldim_estimator_vectorized(X_samps, my_fulldim_output$my_fulldim_estimator)/axis_aligned_heteroskedastic_gamma_pdf_vectorized(X_samps, SimData)
    return(0.5*(sqrt(density_ratio)-1)^2)
}

generate_heteroskedastic_gamma_samples_for_monte_carlo <- function(K_samps){
    opt_data = matrix(0, nrow=K_samps, ncol=d)
    for (dind in 1:d) {
        opt_data[,dind] <- rgamma(K_samps, shape=SimData$covariance_Z[dind,dind])
    }
    return(opt_data)
}

K_samps <- 10000
num_repeats_mc <- 100

hellinger_error_estimate_statistics_logcondens <- naive_monte_carlo_integrate_repeated(hfun_logcondens, 
                                                    generate_heteroskedastic_gamma_samples_for_monte_carlo, K_samps, num_repeats_mc)

hellinger_error_estimate_statistics_fulldim <- naive_monte_carlo_integrate_repeated(hfun_fulldim, 
                                                    generate_heteroskedastic_gamma_samples_for_monte_carlo, K_samps, num_repeats_mc)

# %%
print(hellinger_error_estimate_statistics_logcondens$mean_val)
print(hellinger_error_estimate_statistics_logcondens$sd_val)
# Out:
# [1] 0.01184326
# [1] 0.0020044

# %%
print(hellinger_error_estimate_statistics_fulldim$mean_val)
print(hellinger_error_estimate_statistics_fulldim$sd_val)
# Out:
# [1] 0.008470193
# [1] 0.0005310059

# %%
# Plotting densities
xg <- seq(-1, 14, by=.2)
yg <- seq(-1, 12, by=.2)

gridmat <- data.matrix(expand.grid(xg, yg))

# %%
z_vals_gt <- matrix(axis_aligned_heteroskedastic_gamma_pdf_vectorized(gridmat, SimData), nrow=length(xg))

z_vals_fulldim <- matrix(evaluate_fulldim_estimator_vectorized(gridmat, my_fulldim_output$my_fulldim_estimator), nrow=length(xg))

z_vals_lcic <- matrix(evaluate_logcondens_estimator_vectorized(gridmat, my_estimator_logcondens), nrow=length(xg))

# %%
# dev.new(width=7, height=4, unit="in")
theta <- 130
phi <- 20
# pdf(file='Results/First-figures/compare-visually-gamma.pdf', width=14, height=10)
options(repr.plot.width = 14, repr.plot.height = 10)
par(mfrow = c(2, 3))
persp(xg, yg, z_vals_gt, theta=theta, phi=phi, box=FALSE)
persp(xg, yg, z_vals_fulldim, theta=theta, phi=phi, box=FALSE)
persp(xg, yg, z_vals_lcic, theta=theta, phi=phi, box=FALSE)

contour(xg, yg, z_vals_gt, xlab=expression(x[1]), ylab=expression(x[2]), cex.lab=1.5, cex.axis=1.5, drawlabels=FALSE)
contour(xg, yg, z_vals_fulldim, xlab=expression(x[1]), ylab=expression(x[2]), cex.lab=1.5, cex.axis=1.5, drawlabels=FALSE)
contour(xg, yg, z_vals_lcic, xlab=expression(x[1]), ylab=expression(x[2]), cex.lab=1.5, cex.axis=1.5, drawlabels=FALSE)
# dev.off()
# Out:
# png
#   2

# %%
# ?par

# %%
# TestData <- get_axis_aligned_heteroskedastic_gamma_data(2, 3000, Sigma_max=7, eigensep=1)
# options(repr.plot.width = 7, repr.plot.height = 7)
# plot(x=TestData$pre_data[,1], y=TestData$pre_data[,2], asp=1)

# %% [markdown]
# # Comparison plots (Gaussian)

# %%
retrieve_d2 <- readRDS('Results/comparisons_over_n_d=2.RData')
retrieve_d3 <- readRDS('Results/comparisons_over_n_d=3.RData')
retrieve_d4 <- readRDS('Results/comparisons_over_n_d=4.RData')

# %%
# Convert to matrix

convert_to_matrix <- function(retrieved_comparison_data) {

    num_exp <- length(retrieved_comparison_data)
    results_mat <- matrix(nrow=num_exp ,ncol=8)
    colnames(results_mat) <- c("n", "d", "irep", "time_taken_logcondens", "time_taken_fulldim", "optflag", 
                              "hell_err_mean_logcondens", "hell_err_mean_fulldim")
    
    for (eind in 1:num_exp){
        results_mat[eind, "n"] <- retrieved_comparison_data[[eind]]$n
        results_mat[eind, "d"] <- retrieved_comparison_data[[eind]]$d
        results_mat[eind, "irep"] <- retrieved_comparison_data[[eind]]$irep
        results_mat[eind, "time_taken_logcondens"] <- retrieved_comparison_data[[eind]]$time_taken_logcondens
        results_mat[eind, "time_taken_fulldim"] <- retrieved_comparison_data[[eind]]$time_taken_fulldim
        results_mat[eind, "optflag"] <- retrieved_comparison_data[[eind]]$optflag
        results_mat[eind, "hell_err_mean_logcondens"] <- retrieved_comparison_data[[eind]]$hell_err_mean_logcondens
        results_mat[eind, "hell_err_mean_fulldim"] <- retrieved_comparison_data[[eind]]$hell_err_mean_fulldim
    }
    return(results_mat)
    
}

# %%
results_mat_d2 <- convert_to_matrix(retrieve_d2)
results_mat_d2 <- results_mat_d2[results_mat_d2[,"n"]<4000,]
results_mat_d3 <- convert_to_matrix(retrieve_d3)
results_mat_d4 <- convert_to_matrix(retrieve_d4)

# %%
get_ave_metric <- function(results_mat, all_n, metric_string){
    num_n_vals <- length(all_n)
    ave_metric_vec <- rep(0,num_n_vals)
    for (nvind in 1:num_n_vals){
        where_n <- (results_mat[,"n"]==all_n[nvind])
        ave_metric_vec[nvind] <- mean(results_mat[where_n, metric_string])
    }
    return(ave_metric_vec)
}

# %%
all_n <- c(100, 500, 1000, 2000, 3000)

# %%
pdf(file='Results/First-figures/compare-error-graphs-gaussian-new.pdf', width=15, height=5)
options(repr.plot.width = 15, repr.plot.height = 5)
par(mfrow = c(1, 3), mar=c(6,6,4,2))

point_alpha <- 0.3
line_alpha <- 1
pch <- 19
lty <- 1

plot(x=results_mat_d2[,"n"], y=results_mat_d2[,"hell_err_mean_fulldim"], pch=pch, col=rgb(1,0,0,point_alpha), main=expression(d == 2),
     cex.lab=2, cex.axis=1.5, cex.main=2.5, xlab=expression(n), ylab="Squared hellinger error", ylim=c(0,0.3))
points(x=results_mat_d2[,"n"], y=results_mat_d2[,"hell_err_mean_logcondens"], pch=pch, col=rgb(0,0,1,point_alpha))

lines(x=all_n, y=get_ave_metric(results_mat_d2, all_n, "hell_err_mean_fulldim"), lty=lty, col=rgb(1,0,0,line_alpha))
lines(x=all_n, y=get_ave_metric(results_mat_d2, all_n, "hell_err_mean_logcondens"), lty=lty, col=rgb(0,0,1,line_alpha))
legend(x="topright", legend=c("LC-MLE", "LC-IC"), col=c(rgb(1,0,0,1), rgb(0,0,1,1)), lty=c(lty,lty), 
       cex=1.5, seg.len=3, y.intersp=1.5, bty="n")

####

plot(x=results_mat_d3[,"n"], y=results_mat_d3[,"hell_err_mean_fulldim"], pch=pch, col=rgb(1,0,0,point_alpha), main=expression(d == 3),
     cex.lab=2, cex.axis=1.5, cex.main=2.5, xlab=expression(n), ylab="Squared hellinger error", ylim=c(0,0.3))
points(x=results_mat_d3[,"n"], y=results_mat_d3[,"hell_err_mean_logcondens"], pch=pch, col=rgb(0,0,1,point_alpha))

lines(x=all_n, y=get_ave_metric(results_mat_d3, all_n, "hell_err_mean_fulldim"), lty=lty, col=rgb(1,0,0,line_alpha))
lines(x=all_n, y=get_ave_metric(results_mat_d3, all_n, "hell_err_mean_logcondens"), lty=lty, col=rgb(0,0,1,line_alpha))
legend(x="topright", legend=c("LC-MLE", "LC-IC"), col=c(rgb(1,0,0,1), rgb(0,0,1,1)), lty=c(lty,lty), 
       cex=1.5, seg.len=3, y.intersp=1.5, bty="n")


###

plot(x=results_mat_d4[,"n"], y=results_mat_d4[,"hell_err_mean_fulldim"], pch=pch, col=rgb(1,0,0,point_alpha), main=expression(d == 4),
     cex.lab=2, cex.axis=1.5, cex.main=2.5, xlab=expression(n), ylab="Squared hellinger error", ylim=c(0,0.3))
points(x=results_mat_d4[,"n"], y=results_mat_d4[,"hell_err_mean_logcondens"], pch=pch, col=rgb(0,0,1,point_alpha))

lines(x=all_n, y=get_ave_metric(results_mat_d4, all_n, "hell_err_mean_fulldim"), lty=lty, col=rgb(1,0,0,line_alpha))
lines(x=all_n, y=get_ave_metric(results_mat_d4, all_n, "hell_err_mean_logcondens"), lty=lty, col=rgb(0,0,1,line_alpha))
legend(x="topright", legend=c("LC-MLE", "LC-IC"), col=c(rgb(1,0,0,1), rgb(0,0,1,1)), lty=c(lty,lty), 
       cex=1.5, seg.len=3, y.intersp=1.5, bty="n")

dev.off()
# ###

# plot(x=results_mat_d2[,"n"], y=results_mat_d2[,"time_taken_fulldim"], pch=pch, col=rgb(1,0,0,point_alpha), main=expression(d == 2),
#      cex.lab=2, cex.axis=1.5, cex.main=2.5, xlab=expression(n), ylab="Runtime (sec)", ylim=c(1e-2, 1e+5), log="y")
# points(x=results_mat_d2[,"n"], y=results_mat_d2[,"time_taken_logcondens"], pch=pch, col=rgb(0,0,1,point_alpha))

# lines(x=all_n, y=get_ave_metric(results_mat_d2, all_n, "time_taken_fulldim"), lty=lty, col=rgb(1,0,0,line_alpha))
# lines(x=all_n, y=get_ave_metric(results_mat_d2, all_n, "time_taken_logcondens"), lty=lty, col=rgb(0,0,1,line_alpha))

# ###

# plot(x=results_mat_d3[,"n"], y=results_mat_d3[,"time_taken_fulldim"], pch=pch, col=rgb(1,0,0,point_alpha), main=expression(d == 3),
#      cex.lab=2, cex.axis=1.5, cex.main=2.5, xlab=expression(n), ylab="Runtime (sec)", ylim=c(1e-2, 1e+5), log="y")
# points(x=results_mat_d3[,"n"], y=results_mat_d3[,"time_taken_logcondens"], pch=pch, col=rgb(0,0,1,point_alpha))

# lines(x=all_n, y=get_ave_metric(results_mat_d3, all_n, "time_taken_fulldim"), lty=lty, col=rgb(1,0,0,line_alpha))
# lines(x=all_n, y=get_ave_metric(results_mat_d3, all_n, "time_taken_logcondens"), lty=lty, col=rgb(0,0,1,line_alpha))


# ###

# plot(x=results_mat_d4[,"n"], y=results_mat_d4[,"time_taken_fulldim"], pch=pch, col=rgb(1,0,0,point_alpha), main=expression(d == 4),
#      cex.lab=2, cex.axis=1.5, cex.main=2.5, xlab=expression(n), ylab="Runtime (sec)", ylim=c(1e-2, 1e+5), log="y")
# points(x=results_mat_d4[,"n"], y=results_mat_d4[,"time_taken_logcondens"], pch=pch, col=rgb(0,0,1,point_alpha))

# lines(x=all_n, y=get_ave_metric(results_mat_d4, all_n, "time_taken_fulldim"), lty=lty, col=rgb(1,0,0,line_alpha))
# lines(x=all_n, y=get_ave_metric(results_mat_d4, all_n, "time_taken_logcondens"), lty=lty, col=rgb(0,0,1,line_alpha))
# Out:
# png
#   2

# %% [markdown]
# ### Times

# %%
print(get_ave_metric(results_mat_d4, all_n, "time_taken_fulldim"))
print(get_ave_metric(results_mat_d4, all_n, "time_taken_logcondens"))
# Out:
# [1]     8.700557   155.032099   735.063687  4361.811291 12933.452472
# [1] 0.03210287 0.06657495 0.10816503 0.15718136 0.23946867

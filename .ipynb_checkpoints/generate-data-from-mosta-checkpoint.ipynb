# %%
import os
import time
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import scanpy as sc
import seaborn as sns

from sklearn.decomposition import PCA

# %%
INDIR = "/mnt/geofflab/st_denoising_data/adata/"
# Input files
my_dataset = "StereoSeq"
dataset = my_dataset


# Load data
adata = sc.read_h5ad(os.path.join(INDIR,'Mouse_embryo_E9_5.h5ad'))
# Out:
# AnnData object with n_obs × n_vars = 5913 × 23761
#     obs: 'annotation', 'timepoint', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_50_genes', 'pct_counts_in_top_100_genes', 'pct_counts_in_top_200_genes', 'pct_counts_in_top_500_genes'
#     var: 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts'
#     uns: 'annotation_colors'
#     obsm: 'spatial'
#     layers: 'count'

# %%
adata = adata[adata.obs.annotation != 'Cavity']

# %%
sc.tl.pca(adata, n_comps=50)
adata
# Out:
# AnnData object with n_obs × n_vars = 5031 × 23761
#     obs: 'annotation', 'timepoint', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_50_genes', 'pct_counts_in_top_100_genes', 'pct_counts_in_top_200_genes', 'pct_counts_in_top_500_genes'
#     var: 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts'
#     uns: 'annotation_colors', 'pca'
#     obsm: 'spatial', 'X_pca'
#     varm: 'PCs'
#     layers: 'count'

# %%
adata.obs
# Out:
#            annotation timepoint  n_genes_by_counts  log1p_n_genes_by_counts  \
# cell_name
# 147_108-0  Mesenchyme      E9.5               1626                 7.394493
# 147_109-0  Mesenchyme      E9.5               1765                 7.476472
# 147_110-0  Mesenchyme      E9.5               1815                 7.504392
# 147_111-0  Mesenchyme      E9.5               1797                 7.494430
# 147_112-0  Mesenchyme      E9.5               1851                 7.524021
# ...               ...       ...                ...                      ...
# 252_112-0       Brain      E9.5               3491                 8.158230
# 252_113-0       Brain      E9.5               3230                 8.080547
# 252_114-0       Brain      E9.5               3114                 8.043984
# 252_115-0       Brain      E9.5               2957                 7.992269
# 252_116-0       Brain      E9.5               2003                 7.602900
#
# ...

# %%
plt.stem((adata.uns['pca']['variance_ratio']))
adata.uns['pca']['variance']
# Out:
# array([54.03288689, 24.68188192, 19.90402489, 18.32985679,  9.68410584,
#         7.99910554,  7.32594575,  5.75247962,  4.88637371,  4.33146641,
#         4.08657323,  3.70808972,  3.41874229,  3.01882594,  2.82911478,
#         2.71432698,  2.54412048,  2.4938874 ,  2.36882158,  2.24492081,
#         2.0864011 ,  2.03174395,  1.9590754 ,  1.94350116,  1.87460197,
#         1.84970545,  1.78401589,  1.77928903,  1.73347191,  1.72171072,
#         1.70686074,  1.69755355,  1.69403677,  1.69171465,  1.68078064,
#         1.67495479,  1.66626772,  1.66417407,  1.66122262,  1.65813753,
#         1.654476  ,  1.65141012,  1.64525566,  1.64322958,  1.64239456,
#         1.63886374,  1.6352907 ,  1.6321915 ,  1.63038477,  1.62655252])

# %%
sc.pl.pca(adata, color='annotation', annotate_var_explained=True, alpha=0.4, s=12)
# Out:
# /zfs/users/sharvaj/sharvaj/moscot_env_3_8/lib64/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
adata.obsm['X_pca'].shape
# Out:
# (5031, 50)

# %%
np.savetxt('mosta_E9_5_pca.csv', adata.obsm['X_pca'], delimiter=',')

# %%
adata.obs.annotation.to_csv('mosta_E9_5_anno.csv')
